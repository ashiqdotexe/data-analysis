# %%
print("Hello world")
# Out:
# Hello world

# %%
multiline = """
I am here typing the multiline "string". 
And my name is HM Ashiqur Rahman
"""

# %%
print(multiline)
# Out:
# I am here typing the multiline "string".
# And my name is HM Ashiqur Rahman

# %%
type(multiline)
# Out:
# str

# %%
h = "Hello world"
print(h[6])
# Out:
# w

# %%
print(h[:5])
# Out:
# Hello

# %%
#List
